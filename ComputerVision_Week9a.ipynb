# %% [markdown]
# # Face Detection

# %%
from google.colab import drive
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
drive.mount('/content/gdrive', force_remount=True)

alanturing = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/AlanTuring.jpg',0)
plt.imshow(alanturing,cmap='gray')
# Out:
# Mounted at /content/gdrive

# %%
gracehopper = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/GraceHopper.jpg',0)
plt.imshow(gracehopper,cmap='gray')

# %%
codebreakers = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/CodeBreakers.jpg',0)
plt.imshow(codebreakers,cmap='gray')

# %% [markdown]
# **Haar Cascade**

# %%
face_cascade = cv2.CascadeClassifier('/content/gdrive/My Drive/Colab Notebooks/haarcascades/haarcascade_frontalface_default.xml')

# %%
def detect_face(img):
    
  
    face_img = img.copy()
  
    face_rects = face_cascade.detectMultiScale(face_img) 
    
    for (x,y,w,h) in face_rects: 
        cv2.rectangle(face_img, (x,y), (x+w,y+h), (255,255,255), 10) 
        
    return face_img

# %%
plt.imshow(detect_face(gracehopper),cmap='gray')

# %%
plt.imshow(detect_face(codebreakers),cmap='gray')

# %%
plt.imshow(detect_face(alanturing),cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('/content/gdrive/My Drive/Colab Notebooks/haarcascades/haarcascade_profileface.xml')

# %%
plt.imshow(detect_face(alanturing),cmap='gray')

# %% [markdown]
# **Eye Detection**

# %%
#Reset to Frontal Face
face_cascade = cv2.CascadeClassifier('/content/gdrive/My Drive/Colab Notebooks/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('/content/gdrive/My Drive/Colab Notebooks/haarcascades/haarcascade_eye_tree_eyeglasses.xml')

# %%
def detect_eyes(img):
    
    face_img = img.copy()
  
    eyes = eye_cascade.detectMultiScale(face_img) 
    
    
    for (x,y,w,h) in eyes: 
        cv2.rectangle(face_img, (x,y), (x+w,y+h), (255,255,255), 10) 
        
    return face_img

# %%
plt.imshow(detect_eyes(gracehopper),cmap='gray')

# %% [markdown]
# **Video**

# %%
#It is also possible to complete face detection in Video but not on Colab. You will need to take this to Jupyter Notebook running locally.

#cap = cv2.VideoCapture(0) 

#while True: 
    
#    ret, frame = cap.read(0) 
     
#    frame = detect_face(frame)
 
#    cv2.imshow('Video Face Detection', frame) 
 
#    c = cv2.waitKey(1) 
#    if c == 27: 
#        break 
        
#cap.release() 
#cv2.destroyAllWindows()

# %% [markdown]
# # Challenge
#
# Often we need to anonymise photographs. We have looked at detecting a face in this practical. Use the skills you have learned from previous practicals to determine a Region of Interest and apply a Median Blur.

# %%
plt.imshow(blurface(gracehopper),cmap='gray')
